# %% [markdown]
# # Data Merger v1.7

# %% [markdown]
# https://www.google.it/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwi1_ZKWsPf0AhVAg_0HHTfwCnEQwqsBegQIBBAB&url=https%3A%2F%2Fwww.facebook.com%2Flefognedinapoli%2Fvideos%2Ft-fox-nderr-merg-che-frat-fidate-voi-lo-sapete-che-significa-t-foxun-ringraziame%2F171655443412936%2F&usg=AOvVaw2ahbE7KNdrO-m0HpRHNs5n

# %%
import os
import sys
import pandas as pd  
import numpy  as np
import datetime
from datetime import datetime
import math

DIR = sys.path[0]

# %%
df1  = pd.read_csv(os.path.join(DIR,'Data','df1.csv'), sep = ",").drop(columns="Unnamed: 0");
df2  = pd.read_csv(os.path.join(DIR,'Data','df2.csv'), sep = ",").drop(columns="Unnamed: 0");
df3  = pd.read_csv(os.path.join(DIR,'Data','df3.csv'), sep = ",").drop(columns="Unnamed: 0");
df4  = pd.read_csv(os.path.join(DIR,'Data','df4.csv'), sep = ",").drop(columns="Unnamed: 0");
df5  = pd.read_csv(os.path.join(DIR,'Data','df5.csv'), sep = ",").drop(columns="Unnamed: 0");
df6  = pd.read_csv(os.path.join(DIR,'Data','df6.csv'), sep = ",").drop(columns="Unnamed: 0");
df7  = pd.read_csv(os.path.join(DIR,'Data','df7.csv'), sep = ",").drop(columns="Unnamed: 0");
df8  = pd.read_csv(os.path.join(DIR,'Data','df8.csv'), sep = ",").drop(columns="Unnamed: 0");
df9  = pd.read_csv(os.path.join(DIR,'Data','df9.csv'), sep = ",").drop(columns="Unnamed: 0");

df10 = pd.read_csv(os.path.join(DIR,'Data','df10.csv'),sep = ",").drop(columns="Unnamed: 0");
df11 = pd.read_csv(os.path.join(DIR,'Data','df11.csv'),sep = ",").drop(columns="Unnamed: 0");
df12 = pd.read_csv(os.path.join(DIR,'Data','df12.csv'),sep = ",").drop(columns="Unnamed: 0");
df13 = pd.read_csv(os.path.join(DIR,'Data','df13.csv'),sep = ",").drop(columns="Unnamed: 0");
df14 = pd.read_csv(os.path.join(DIR,'Data','df14.csv'),sep = ",").drop(columns="Unnamed: 0");
df15 = pd.read_csv(os.path.join(DIR,'Data','df15.csv'),sep = ",").drop(columns="Unnamed: 0");
df16 = pd.read_csv(os.path.join(DIR,'Data','df16.csv'),sep = ",").drop(columns="Unnamed: 0");
df17 = pd.read_csv(os.path.join(DIR,'Data','df17.csv'),sep = ",").drop(columns="Unnamed: 0");
df18 = pd.read_csv(os.path.join(DIR,'Data','df18.csv'),sep = ",").drop(columns="Unnamed: 0");
df19 = pd.read_csv(os.path.join(DIR,'Data','df19.csv'),sep = ",").drop(columns="Unnamed: 0");

df20 = pd.read_csv(os.path.join(DIR,'Data','df20.csv'),sep = ",").drop(columns="Unnamed: 0");
df21 = pd.read_csv(os.path.join(DIR,'Data','df21.csv'),sep = ",").drop(columns="Unnamed: 0");
df22 = pd.read_csv(os.path.join(DIR,'Data','df22.csv'),sep = ",").drop(columns="Unnamed: 0");
df23 = pd.read_csv(os.path.join(DIR,'Data','df23.csv'),sep = ",").drop(columns="Unnamed: 0");
df24 = pd.read_csv(os.path.join(DIR,'Data','df24.csv'),sep = ",").drop(columns="Unnamed: 0");
df25 = pd.read_csv(os.path.join(DIR,'Data','df25.csv'),sep = ",").drop(columns="Unnamed: 0");
df26 = pd.read_csv(os.path.join(DIR,'Data','df26.csv'),sep = ",").drop(columns="Unnamed: 0");
df27 = pd.read_csv(os.path.join(DIR,'Data','df27.csv'),sep = ",").drop(columns="Unnamed: 0");
df28 = pd.read_csv(os.path.join(DIR,'Data','df28.csv'),sep = ",").drop(columns="Unnamed: 0");
df29 = pd.read_csv(os.path.join(DIR,'Data','df29.csv'),sep = ",").drop(columns="Unnamed: 0");

df30 = pd.read_csv(os.path.join(DIR,'Data','df30.csv'),sep = ",").drop(columns="Unnamed: 0");
df31 = pd.read_csv(os.path.join(DIR,'Data','df31.csv'),sep = ",").drop(columns="Unnamed: 0");
df32 = pd.read_csv(os.path.join(DIR,'Data','df32.csv'),sep = ",").drop(columns="Unnamed: 0");
df33 = pd.read_csv(os.path.join(DIR,'Data','df33.csv'),sep = ",").drop(columns="Unnamed: 0");
df34 = pd.read_csv(os.path.join(DIR,'Data','df34.csv'),sep = ",").drop(columns="Unnamed: 0");
df35 = pd.read_csv(os.path.join(DIR,'Data','df35.csv'),sep = ",").drop(columns="Unnamed: 0");
df36 = pd.read_csv(os.path.join(DIR,'Data','df36.csv'),sep = ",").drop(columns="Unnamed: 0");
df37 = pd.read_csv(os.path.join(DIR,'Data','df37.csv'),sep = ",").drop(columns="Unnamed: 0");
df38 = pd.read_csv(os.path.join(DIR,'Data','df38.csv'),sep = ",").drop(columns="Unnamed: 0");
df39 = pd.read_csv(os.path.join(DIR,'Data','df39.csv'),sep = ",").drop(columns="Unnamed: 0");

df40 = pd.read_csv(os.path.join(DIR,'Data','df40.csv'),sep = ",").drop(columns="Unnamed: 0");
df41 = pd.read_csv(os.path.join(DIR,'Data','df41.csv'),sep = ",").drop(columns="Unnamed: 0");
df42 = pd.read_csv(os.path.join(DIR,'Data','df42.csv'),sep = ",").drop(columns="Unnamed: 0");
df43 = pd.read_csv(os.path.join(DIR,'Data','df43.csv'),sep = ",").drop(columns="Unnamed: 0");
df44 = pd.read_csv(os.path.join(DIR,'Data','df44.csv'),sep = ",").drop(columns="Unnamed: 0");
df45 = pd.read_csv(os.path.join(DIR,'Data','df45.csv'),sep = ",").drop(columns="Unnamed: 0");
df46 = pd.read_csv(os.path.join(DIR,'Data','df46.csv'),sep = ",").drop(columns="Unnamed: 0");
df47 = pd.read_csv(os.path.join(DIR,'Data','df47.csv'),sep = ",").drop(columns="Unnamed: 0");
df48 = pd.read_csv(os.path.join(DIR,'Data','df48.csv'),sep = ",").drop(columns="Unnamed: 0");
df49 = pd.read_csv(os.path.join(DIR,'Data','df49.csv'),sep = ",").drop(columns="Unnamed: 0");

df50 = pd.read_csv(os.path.join(DIR,'Data','df50.csv'),sep = ",").drop(columns="Unnamed: 0");
df51 = pd.read_csv(os.path.join(DIR,'Data','df51.csv'),sep = ",").drop(columns="Unnamed: 0");
df52 = pd.read_csv(os.path.join(DIR,'Data','df52.csv'),sep = ",").drop(columns="Unnamed: 0");
df53 = pd.read_csv(os.path.join(DIR,'Data','df53.csv'),sep = ",").drop(columns="Unnamed: 0");
df54 = pd.read_csv(os.path.join(DIR,'Data','df54.csv'),sep = ",").drop(columns="Unnamed: 0");
df55 = pd.read_csv(os.path.join(DIR,'Data','df55.csv'),sep = ",").drop(columns="Unnamed: 0");
df56 = pd.read_csv(os.path.join(DIR,'Data','df56.csv'),sep = ",").drop(columns="Unnamed: 0");
df57 = pd.read_csv(os.path.join(DIR,'Data','df57.csv'),sep = ",").drop(columns="Unnamed: 0");
df58 = pd.read_csv(os.path.join(DIR,'Data','df58.csv'),sep = ",").drop(columns="Unnamed: 0");
df59 = pd.read_csv(os.path.join(DIR,'Data','df59.csv'),sep = ",").drop(columns="Unnamed: 0");

df60 = pd.read_csv(os.path.join(DIR,'Data','df60.csv'),sep = ",").drop(columns="Unnamed: 0");
df61 = pd.read_csv(os.path.join(DIR,'Data','df61.csv'),sep = ",").drop(columns="Unnamed: 0");
df62 = pd.read_csv(os.path.join(DIR,'Data','df62.csv'),sep = ",").drop(columns="Unnamed: 0");
df63 = pd.read_csv(os.path.join(DIR,'Data','df63.csv'),sep = ",").drop(columns="Unnamed: 0");
df64 = pd.read_csv(os.path.join(DIR,'Data','df64.csv'),sep = ",").drop(columns="Unnamed: 0");
df65 = pd.read_csv(os.path.join(DIR,'Data','df65.csv'),sep = ",").drop(columns="Unnamed: 0");
df66 = pd.read_csv(os.path.join(DIR,'Data','df66.csv'),sep = ",").drop(columns="Unnamed: 0");
df67 = pd.read_csv(os.path.join(DIR,'Data','df67.csv'),sep = ",").drop(columns="Unnamed: 0");
df68 = pd.read_csv(os.path.join(DIR,'Data','df68.csv'),sep = ",").drop(columns="Unnamed: 0");
df69 = pd.read_csv(os.path.join(DIR,'Data','df69.csv'),sep = ",").drop(columns="Unnamed: 0");

df70 = pd.read_csv(os.path.join(DIR,'Data','df70.csv'),sep = ",").drop(columns="Unnamed: 0");
df71 = pd.read_csv(os.path.join(DIR,'Data','df71.csv'),sep = ",").drop(columns="Unnamed: 0");
df72 = pd.read_csv(os.path.join(DIR,'Data','df72.csv'),sep = ",").drop(columns="Unnamed: 0");
df73 = pd.read_csv(os.path.join(DIR,'Data','df73.csv'),sep = ",").drop(columns="Unnamed: 0");
df74 = pd.read_csv(os.path.join(DIR,'Data','df74.csv'),sep = ",").drop(columns="Unnamed: 0");
df75 = pd.read_csv(os.path.join(DIR,'Data','df75.csv'),sep = ",").drop(columns="Unnamed: 0");
df76 = pd.read_csv(os.path.join(DIR,'Data','df76.csv'),sep = ",").drop(columns="Unnamed: 0");
df77 = pd.read_csv(os.path.join(DIR,'Data','df77.csv'),sep = ",").drop(columns="Unnamed: 0");
df78 = pd.read_csv(os.path.join(DIR,'Data','df78.csv'),sep = ",").drop(columns="Unnamed: 0");
df79 = pd.read_csv(os.path.join(DIR,'Data','df79.csv'),sep = ",").drop(columns="Unnamed: 0");

df80 = pd.read_csv(os.path.join(DIR,'Data','df80.csv'),sep = ",").drop(columns="Unnamed: 0");
df81 = pd.read_csv(os.path.join(DIR,'Data','df81.csv'),sep = ",").drop(columns="Unnamed: 0");
df82 = pd.read_csv(os.path.join(DIR,'Data','df82.csv'),sep = ",").drop(columns="Unnamed: 0");
df83 = pd.read_csv(os.path.join(DIR,'Data','df83.csv'),sep = ",").drop(columns="Unnamed: 0");
df84 = pd.read_csv(os.path.join(DIR,'Data','df84.csv'),sep = ",").drop(columns="Unnamed: 0");
df85 = pd.read_csv(os.path.join(DIR,'Data','df85.csv'),sep = ",").drop(columns="Unnamed: 0");
df86 = pd.read_csv(os.path.join(DIR,'Data','df86.csv'),sep = ",").drop(columns="Unnamed: 0");
df87 = pd.read_csv(os.path.join(DIR,'Data','df87.csv'),sep = ",").drop(columns="Unnamed: 0");
df88 = pd.read_csv(os.path.join(DIR,'Data','df88.csv'),sep = ",").drop(columns="Unnamed: 0");
df89 = pd.read_csv(os.path.join(DIR,'Data','df89.csv'),sep = ",").drop(columns="Unnamed: 0");

df90 = pd.read_csv(os.path.join(DIR,'Data','df90.csv'),sep = ",").drop(columns="Unnamed: 0");
df91 = pd.read_csv(os.path.join(DIR,'Data','df91.csv'),sep = ",").drop(columns="Unnamed: 0");
df92 = pd.read_csv(os.path.join(DIR,'Data','df92.csv'),sep = ",").drop(columns="Unnamed: 0");
df93 = pd.read_csv(os.path.join(DIR,'Data','df93.csv'),sep = ",").drop(columns="Unnamed: 0");
df94 = pd.read_csv(os.path.join(DIR,'Data','df94.csv'),sep = ",").drop(columns="Unnamed: 0");
df95 = pd.read_csv(os.path.join(DIR,'Data','df95.csv'),sep = ",").drop(columns="Unnamed: 0");
df96 = pd.read_csv(os.path.join(DIR,'Data','df96.csv'),sep = ",").drop(columns="Unnamed: 0");
df97 = pd.read_csv(os.path.join(DIR,'Data','df97.csv'),sep = ",").drop(columns="Unnamed: 0");
df98 = pd.read_csv(os.path.join(DIR,'Data','df98.csv'),sep = ",").drop(columns="Unnamed: 0");
df99 = pd.read_csv(os.path.join(DIR,'Data','df99.csv'),sep = ",").drop(columns="Unnamed: 0");

# %%
df100 = pd.read_csv(os.path.join(DIR,'Data','df100.csv'),sep = ",").drop(columns="Unnamed: 0");
df101 = pd.read_csv(os.path.join(DIR,'Data','df101.csv'),sep = ",").drop(columns="Unnamed: 0");
df102 = pd.read_csv(os.path.join(DIR,'Data','df102.csv'),sep = ",").drop(columns="Unnamed: 0");
df103 = pd.read_csv(os.path.join(DIR,'Data','df103.csv'),sep = ",").drop(columns="Unnamed: 0");
df104 = pd.read_csv(os.path.join(DIR,'Data','df104.csv'),sep = ",").drop(columns="Unnamed: 0");
df105 = pd.read_csv(os.path.join(DIR,'Data','df105.csv'),sep = ",").drop(columns="Unnamed: 0");
df106 = pd.read_csv(os.path.join(DIR,'Data','df106.csv'),sep = ",").drop(columns="Unnamed: 0");
df107 = pd.read_csv(os.path.join(DIR,'Data','df107.csv'),sep = ",").drop(columns="Unnamed: 0");
df108 = pd.read_csv(os.path.join(DIR,'Data','df108.csv'),sep = ",").drop(columns="Unnamed: 0");
df109 = pd.read_csv(os.path.join(DIR,'Data','df109.csv'),sep = ",").drop(columns="Unnamed: 0");

df110 = pd.read_csv(os.path.join(DIR,'Data','df110.csv'),sep = ",").drop(columns="Unnamed: 0");
df111 = pd.read_csv(os.path.join(DIR,'Data','df111.csv'),sep = ",").drop(columns="Unnamed: 0");
df112 = pd.read_csv(os.path.join(DIR,'Data','df112.csv'),sep = ",").drop(columns="Unnamed: 0");
df113 = pd.read_csv(os.path.join(DIR,'Data','df113.csv'),sep = ",").drop(columns="Unnamed: 0");
df114 = pd.read_csv(os.path.join(DIR,'Data','df114.csv'),sep = ",").drop(columns="Unnamed: 0");
df115 = pd.read_csv(os.path.join(DIR,'Data','df115.csv'),sep = ",").drop(columns="Unnamed: 0");
df116 = pd.read_csv(os.path.join(DIR,'Data','df116.csv'),sep = ",").drop(columns="Unnamed: 0");
df117 = pd.read_csv(os.path.join(DIR,'Data','df117.csv'),sep = ",").drop(columns="Unnamed: 0");
df118 = pd.read_csv(os.path.join(DIR,'Data','df118.csv'),sep = ",").drop(columns="Unnamed: 0");
df119 = pd.read_csv(os.path.join(DIR,'Data','df119.csv'),sep = ",").drop(columns="Unnamed: 0");

df120 = pd.read_csv(os.path.join(DIR,'Data','df120.csv'),sep = ",").drop(columns="Unnamed: 0");
df121 = pd.read_csv(os.path.join(DIR,'Data','df121.csv'),sep = ",").drop(columns="Unnamed: 0");
df122 = pd.read_csv(os.path.join(DIR,'Data','df122.csv'),sep = ",").drop(columns="Unnamed: 0");
df123 = pd.read_csv(os.path.join(DIR,'Data','df123.csv'),sep = ",").drop(columns="Unnamed: 0");
df124 = pd.read_csv(os.path.join(DIR,'Data','df124.csv'),sep = ",").drop(columns="Unnamed: 0");
df125 = pd.read_csv(os.path.join(DIR,'Data','df125.csv'),sep = ",").drop(columns="Unnamed: 0");
df126 = pd.read_csv(os.path.join(DIR,'Data','df126.csv'),sep = ",").drop(columns="Unnamed: 0");
df127 = pd.read_csv(os.path.join(DIR,'Data','df127.csv'),sep = ",").drop(columns="Unnamed: 0");
df128 = pd.read_csv(os.path.join(DIR,'Data','df128.csv'),sep = ",").drop(columns="Unnamed: 0");
df129 = pd.read_csv(os.path.join(DIR,'Data','df129.csv'),sep = ",").drop(columns="Unnamed: 0");

df130 = pd.read_csv(os.path.join(DIR,'Data','df130.csv'),sep = ",").drop(columns="Unnamed: 0");
df131 = pd.read_csv(os.path.join(DIR,'Data','df131.csv'),sep = ",").drop(columns="Unnamed: 0");
df132 = pd.read_csv(os.path.join(DIR,'Data','df132.csv'),sep = ",").drop(columns="Unnamed: 0");
df133 = pd.read_csv(os.path.join(DIR,'Data','df133.csv'),sep = ",").drop(columns="Unnamed: 0");
df134 = pd.read_csv(os.path.join(DIR,'Data','df134.csv'),sep = ",").drop(columns="Unnamed: 0");
df135 = pd.read_csv(os.path.join(DIR,'Data','df135.csv'),sep = ",").drop(columns="Unnamed: 0");
df136 = pd.read_csv(os.path.join(DIR,'Data','df136.csv'),sep = ",").drop(columns="Unnamed: 0");
df137 = pd.read_csv(os.path.join(DIR,'Data','df137.csv'),sep = ",").drop(columns="Unnamed: 0");
df138 = pd.read_csv(os.path.join(DIR,'Data','df138.csv'),sep = ",").drop(columns="Unnamed: 0");
df139 = pd.read_csv(os.path.join(DIR,'Data','df139.csv'),sep = ",").drop(columns="Unnamed: 0");

df140 = pd.read_csv(os.path.join(DIR,'Data','df140.csv'),sep = ",").drop(columns="Unnamed: 0");
df141 = pd.read_csv(os.path.join(DIR,'Data','df141.csv'),sep = ",").drop(columns="Unnamed: 0");
df142 = pd.read_csv(os.path.join(DIR,'Data','df142.csv'),sep = ",").drop(columns="Unnamed: 0");
df143 = pd.read_csv(os.path.join(DIR,'Data','df143.csv'),sep = ",").drop(columns="Unnamed: 0");
df144 = pd.read_csv(os.path.join(DIR,'Data','df144.csv'),sep = ",").drop(columns="Unnamed: 0");
df145 = pd.read_csv(os.path.join(DIR,'Data','df145.csv'),sep = ",").drop(columns="Unnamed: 0");
df146 = pd.read_csv(os.path.join(DIR,'Data','df146.csv'),sep = ",").drop(columns="Unnamed: 0");
df147 = pd.read_csv(os.path.join(DIR,'Data','df147.csv'),sep = ",").drop(columns="Unnamed: 0");
df148 = pd.read_csv(os.path.join(DIR,'Data','df148.csv'),sep = ",").drop(columns="Unnamed: 0");
df149 = pd.read_csv(os.path.join(DIR,'Data','df149.csv'),sep = ",").drop(columns="Unnamed: 0");

df150 = pd.read_csv(os.path.join(DIR,'Data','df150.csv'),sep = ",").drop(columns="Unnamed: 0");
df151 = pd.read_csv(os.path.join(DIR,'Data','df151.csv'),sep = ",").drop(columns="Unnamed: 0");
df152 = pd.read_csv(os.path.join(DIR,'Data','df152.csv'),sep = ",").drop(columns="Unnamed: 0");
df153 = pd.read_csv(os.path.join(DIR,'Data','df153.csv'),sep = ",").drop(columns="Unnamed: 0");
df154 = pd.read_csv(os.path.join(DIR,'Data','df154.csv'),sep = ",").drop(columns="Unnamed: 0");
df155 = pd.read_csv(os.path.join(DIR,'Data','df155.csv'),sep = ",").drop(columns="Unnamed: 0");
df156 = pd.read_csv(os.path.join(DIR,'Data','df156.csv'),sep = ",").drop(columns="Unnamed: 0");
df157 = pd.read_csv(os.path.join(DIR,'Data','df157.csv'),sep = ",").drop(columns="Unnamed: 0");
df158 = pd.read_csv(os.path.join(DIR,'Data','df158.csv'),sep = ",").drop(columns="Unnamed: 0");
df159 = pd.read_csv(os.path.join(DIR,'Data','df159.csv'),sep = ",").drop(columns="Unnamed: 0");

df160 = pd.read_csv(os.path.join(DIR,'Data','df160.csv'),sep = ",").drop(columns="Unnamed: 0");
df161 = pd.read_csv(os.path.join(DIR,'Data','df161.csv'),sep = ",").drop(columns="Unnamed: 0");
df162 = pd.read_csv(os.path.join(DIR,'Data','df162.csv'),sep = ",").drop(columns="Unnamed: 0");
df163 = pd.read_csv(os.path.join(DIR,'Data','df163.csv'),sep = ",").drop(columns="Unnamed: 0");
df164 = pd.read_csv(os.path.join(DIR,'Data','df164.csv'),sep = ",").drop(columns="Unnamed: 0");
df165 = pd.read_csv(os.path.join(DIR,'Data','df165.csv'),sep = ",").drop(columns="Unnamed: 0");
df166 = pd.read_csv(os.path.join(DIR,'Data','df166.csv'),sep = ",").drop(columns="Unnamed: 0");
df167 = pd.read_csv(os.path.join(DIR,'Data','df167.csv'),sep = ",").drop(columns="Unnamed: 0");
df168 = pd.read_csv(os.path.join(DIR,'Data','df168.csv'),sep = ",").drop(columns="Unnamed: 0");
df169 = pd.read_csv(os.path.join(DIR,'Data','df169.csv'),sep = ",").drop(columns="Unnamed: 0");

df170 = pd.read_csv(os.path.join(DIR,'Data','df170.csv'),sep = ",").drop(columns="Unnamed: 0");
df171 = pd.read_csv(os.path.join(DIR,'Data','df171.csv'),sep = ",").drop(columns="Unnamed: 0");
df172 = pd.read_csv(os.path.join(DIR,'Data','df172.csv'),sep = ",").drop(columns="Unnamed: 0");
df173 = pd.read_csv(os.path.join(DIR,'Data','df173.csv'),sep = ",").drop(columns="Unnamed: 0");
df174 = pd.read_csv(os.path.join(DIR,'Data','df174.csv'),sep = ",").drop(columns="Unnamed: 0");
df175 = pd.read_csv(os.path.join(DIR,'Data','df175.csv'),sep = ",").drop(columns="Unnamed: 0");
df176 = pd.read_csv(os.path.join(DIR,'Data','df176.csv'),sep = ",").drop(columns="Unnamed: 0");
df177 = pd.read_csv(os.path.join(DIR,'Data','df177.csv'),sep = ",").drop(columns="Unnamed: 0");
df178 = pd.read_csv(os.path.join(DIR,'Data','df178.csv'),sep = ",").drop(columns="Unnamed: 0");
df179 = pd.read_csv(os.path.join(DIR,'Data','df179.csv'),sep = ",").drop(columns="Unnamed: 0");

df180 = pd.read_csv(os.path.join(DIR,'Data','df180.csv'),sep = ",").drop(columns="Unnamed: 0");
df181 = pd.read_csv(os.path.join(DIR,'Data','df181.csv'),sep = ",").drop(columns="Unnamed: 0");
df182 = pd.read_csv(os.path.join(DIR,'Data','df182.csv'),sep = ",").drop(columns="Unnamed: 0");
df183 = pd.read_csv(os.path.join(DIR,'Data','df183.csv'),sep = ",").drop(columns="Unnamed: 0");
df184 = pd.read_csv(os.path.join(DIR,'Data','df184.csv'),sep = ",").drop(columns="Unnamed: 0");
df185 = pd.read_csv(os.path.join(DIR,'Data','df185.csv'),sep = ",").drop(columns="Unnamed: 0");
df186 = pd.read_csv(os.path.join(DIR,'Data','df186.csv'),sep = ",").drop(columns="Unnamed: 0");
df187 = pd.read_csv(os.path.join(DIR,'Data','df187.csv'),sep = ",").drop(columns="Unnamed: 0");
df188 = pd.read_csv(os.path.join(DIR,'Data','df188.csv'),sep = ",").drop(columns="Unnamed: 0");
df189 = pd.read_csv(os.path.join(DIR,'Data','df189.csv'),sep = ",").drop(columns="Unnamed: 0");

df190 = pd.read_csv(os.path.join(DIR,'Data','df190.csv'),sep = ",").drop(columns="Unnamed: 0");
df191 = pd.read_csv(os.path.join(DIR,'Data','df191.csv'),sep = ",").drop(columns="Unnamed: 0");
df192 = pd.read_csv(os.path.join(DIR,'Data','df192.csv'),sep = ",").drop(columns="Unnamed: 0");
df193 = pd.read_csv(os.path.join(DIR,'Data','df193.csv'),sep = ",").drop(columns="Unnamed: 0");
df194 = pd.read_csv(os.path.join(DIR,'Data','df194.csv'),sep = ",").drop(columns="Unnamed: 0");
df195 = pd.read_csv(os.path.join(DIR,'Data','df195.csv'),sep = ",").drop(columns="Unnamed: 0");
df196 = pd.read_csv(os.path.join(DIR,'Data','df196.csv'),sep = ",").drop(columns="Unnamed: 0");
df197 = pd.read_csv(os.path.join(DIR,'Data','df197.csv'),sep = ",").drop(columns="Unnamed: 0");
df198 = pd.read_csv(os.path.join(DIR,'Data','df198.csv'),sep = ",").drop(columns="Unnamed: 0");
df199 = pd.read_csv(os.path.join(DIR,'Data','df199.csv'),sep = ",").drop(columns="Unnamed: 0");

# %%
df200 = pd.read_csv(os.path.join(DIR,'Data','df200.csv'),sep = ",").drop(columns="Unnamed: 0");
df201 = pd.read_csv(os.path.join(DIR,'Data','df201.csv'),sep = ",").drop(columns="Unnamed: 0");
df202 = pd.read_csv(os.path.join(DIR,'Data','df202.csv'),sep = ",").drop(columns="Unnamed: 0");
df203 = pd.read_csv(os.path.join(DIR,'Data','df203.csv'),sep = ",").drop(columns="Unnamed: 0");
df204 = pd.read_csv(os.path.join(DIR,'Data','df204.csv'),sep = ",").drop(columns="Unnamed: 0");
df205 = pd.read_csv(os.path.join(DIR,'Data','df205.csv'),sep = ",").drop(columns="Unnamed: 0");
df206 = pd.read_csv(os.path.join(DIR,'Data','df206.csv'),sep = ",").drop(columns="Unnamed: 0");
df207 = pd.read_csv(os.path.join(DIR,'Data','df207.csv'),sep = ",").drop(columns="Unnamed: 0");
df208 = pd.read_csv(os.path.join(DIR,'Data','df208.csv'),sep = ",").drop(columns="Unnamed: 0");
df209 = pd.read_csv(os.path.join(DIR,'Data','df209.csv'),sep = ",").drop(columns="Unnamed: 0");

df210 = pd.read_csv(os.path.join(DIR,'Data','df210.csv'),sep = ",").drop(columns="Unnamed: 0");
df211 = pd.read_csv(os.path.join(DIR,'Data','df211.csv'),sep = ",").drop(columns="Unnamed: 0");
df212 = pd.read_csv(os.path.join(DIR,'Data','df212.csv'),sep = ",").drop(columns="Unnamed: 0");
df213 = pd.read_csv(os.path.join(DIR,'Data','df213.csv'),sep = ",").drop(columns="Unnamed: 0");
df214 = pd.read_csv(os.path.join(DIR,'Data','df214.csv'),sep = ",").drop(columns="Unnamed: 0");
df215 = pd.read_csv(os.path.join(DIR,'Data','df215.csv'),sep = ",").drop(columns="Unnamed: 0");
df216 = pd.read_csv(os.path.join(DIR,'Data','df216.csv'),sep = ",").drop(columns="Unnamed: 0");
df217 = pd.read_csv(os.path.join(DIR,'Data','df217.csv'),sep = ",").drop(columns="Unnamed: 0");
df218 = pd.read_csv(os.path.join(DIR,'Data','df218.csv'),sep = ",").drop(columns="Unnamed: 0");
df219 = pd.read_csv(os.path.join(DIR,'Data','df219.csv'),sep = ",").drop(columns="Unnamed: 0");

df220 = pd.read_csv(os.path.join(DIR,'Data','df220.csv'),sep = ",").drop(columns="Unnamed: 0");
df221 = pd.read_csv(os.path.join(DIR,'Data','df221.csv'),sep = ",").drop(columns="Unnamed: 0");
df222 = pd.read_csv(os.path.join(DIR,'Data','df222.csv'),sep = ",").drop(columns="Unnamed: 0");
df223 = pd.read_csv(os.path.join(DIR,'Data','df223.csv'),sep = ",").drop(columns="Unnamed: 0");
df224 = pd.read_csv(os.path.join(DIR,'Data','df224.csv'),sep = ",").drop(columns="Unnamed: 0");
df225 = pd.read_csv(os.path.join(DIR,'Data','df225.csv'),sep = ",").drop(columns="Unnamed: 0");
df226 = pd.read_csv(os.path.join(DIR,'Data','df226.csv'),sep = ",").drop(columns="Unnamed: 0");
df227 = pd.read_csv(os.path.join(DIR,'Data','df227.csv'),sep = ",").drop(columns="Unnamed: 0");
df228 = pd.read_csv(os.path.join(DIR,'Data','df228.csv'),sep = ",").drop(columns="Unnamed: 0");
df229 = pd.read_csv(os.path.join(DIR,'Data','df229.csv'),sep = ",").drop(columns="Unnamed: 0");

df230 = pd.read_csv(os.path.join(DIR,'Data','df230.csv'),sep = ",").drop(columns="Unnamed: 0");
df231 = pd.read_csv(os.path.join(DIR,'Data','df231.csv'),sep = ",").drop(columns="Unnamed: 0");
df232 = pd.read_csv(os.path.join(DIR,'Data','df232.csv'),sep = ",").drop(columns="Unnamed: 0");
df233 = pd.read_csv(os.path.join(DIR,'Data','df233.csv'),sep = ",").drop(columns="Unnamed: 0");
df234 = pd.read_csv(os.path.join(DIR,'Data','df234.csv'),sep = ",").drop(columns="Unnamed: 0");
df235 = pd.read_csv(os.path.join(DIR,'Data','df235.csv'),sep = ",").drop(columns="Unnamed: 0");
df236 = pd.read_csv(os.path.join(DIR,'Data','df236.csv'),sep = ",").drop(columns="Unnamed: 0");
df237 = pd.read_csv(os.path.join(DIR,'Data','df237.csv'),sep = ",").drop(columns="Unnamed: 0");
df238 = pd.read_csv(os.path.join(DIR,'Data','df238.csv'),sep = ",").drop(columns="Unnamed: 0");
df239 = pd.read_csv(os.path.join(DIR,'Data','df239.csv'),sep = ",").drop(columns="Unnamed: 0");

df240 = pd.read_csv(os.path.join(DIR,'Data','df240.csv'),sep = ",").drop(columns="Unnamed: 0");
df241 = pd.read_csv(os.path.join(DIR,'Data','df241.csv'),sep = ",").drop(columns="Unnamed: 0");
df242 = pd.read_csv(os.path.join(DIR,'Data','df242.csv'),sep = ",").drop(columns="Unnamed: 0");
df243 = pd.read_csv(os.path.join(DIR,'Data','df243.csv'),sep = ",").drop(columns="Unnamed: 0");
df244 = pd.read_csv(os.path.join(DIR,'Data','df244.csv'),sep = ",").drop(columns="Unnamed: 0");
df245 = pd.read_csv(os.path.join(DIR,'Data','df245.csv'),sep = ",").drop(columns="Unnamed: 0");
df246 = pd.read_csv(os.path.join(DIR,'Data','df246.csv'),sep = ",").drop(columns="Unnamed: 0");
df247 = pd.read_csv(os.path.join(DIR,'Data','df247.csv'),sep = ",").drop(columns="Unnamed: 0");
df248 = pd.read_csv(os.path.join(DIR,'Data','df248.csv'),sep = ",").drop(columns="Unnamed: 0");
df249 = pd.read_csv(os.path.join(DIR,'Data','df249.csv'),sep = ",").drop(columns="Unnamed: 0");

df250 = pd.read_csv(os.path.join(DIR,'Data','df250.csv'),sep = ",").drop(columns="Unnamed: 0");
df251 = pd.read_csv(os.path.join(DIR,'Data','df251.csv'),sep = ",").drop(columns="Unnamed: 0");
df252 = pd.read_csv(os.path.join(DIR,'Data','df252.csv'),sep = ",").drop(columns="Unnamed: 0");
df253 = pd.read_csv(os.path.join(DIR,'Data','df253.csv'),sep = ",").drop(columns="Unnamed: 0");
df254 = pd.read_csv(os.path.join(DIR,'Data','df254.csv'),sep = ",").drop(columns="Unnamed: 0");
df255 = pd.read_csv(os.path.join(DIR,'Data','df255.csv'),sep = ",").drop(columns="Unnamed: 0");
df256 = pd.read_csv(os.path.join(DIR,'Data','df256.csv'),sep = ",").drop(columns="Unnamed: 0");
df257 = pd.read_csv(os.path.join(DIR,'Data','df257.csv'),sep = ",").drop(columns="Unnamed: 0");
df258 = pd.read_csv(os.path.join(DIR,'Data','df258.csv'),sep = ",").drop(columns="Unnamed: 0");
df259 = pd.read_csv(os.path.join(DIR,'Data','df259.csv'),sep = ",").drop(columns="Unnamed: 0");

df260 = pd.read_csv(os.path.join(DIR,'Data','df260.csv'),sep = ",").drop(columns="Unnamed: 0");
df261 = pd.read_csv(os.path.join(DIR,'Data','df261.csv'),sep = ",").drop(columns="Unnamed: 0");
df262 = pd.read_csv(os.path.join(DIR,'Data','df262.csv'),sep = ",").drop(columns="Unnamed: 0");
df263 = pd.read_csv(os.path.join(DIR,'Data','df263.csv'),sep = ",").drop(columns="Unnamed: 0");
df264 = pd.read_csv(os.path.join(DIR,'Data','df264.csv'),sep = ",").drop(columns="Unnamed: 0");
df265 = pd.read_csv(os.path.join(DIR,'Data','df265.csv'),sep = ",").drop(columns="Unnamed: 0");
df266 = pd.read_csv(os.path.join(DIR,'Data','df266.csv'),sep = ",").drop(columns="Unnamed: 0");
df267 = pd.read_csv(os.path.join(DIR,'Data','df267.csv'),sep = ",").drop(columns="Unnamed: 0");
df268 = pd.read_csv(os.path.join(DIR,'Data','df268.csv'),sep = ",").drop(columns="Unnamed: 0");
df269 = pd.read_csv(os.path.join(DIR,'Data','df269.csv'),sep = ",").drop(columns="Unnamed: 0");

df270 = pd.read_csv(os.path.join(DIR,'Data','df270.csv'),sep = ",").drop(columns="Unnamed: 0");
df271 = pd.read_csv(os.path.join(DIR,'Data','df271.csv'),sep = ",").drop(columns="Unnamed: 0");
df272 = pd.read_csv(os.path.join(DIR,'Data','df272.csv'),sep = ",").drop(columns="Unnamed: 0");
df273 = pd.read_csv(os.path.join(DIR,'Data','df273.csv'),sep = ",").drop(columns="Unnamed: 0");
df274 = pd.read_csv(os.path.join(DIR,'Data','df274.csv'),sep = ",").drop(columns="Unnamed: 0");
df275 = pd.read_csv(os.path.join(DIR,'Data','df275.csv'),sep = ",").drop(columns="Unnamed: 0");
df276 = pd.read_csv(os.path.join(DIR,'Data','df276.csv'),sep = ",").drop(columns="Unnamed: 0");
df277 = pd.read_csv(os.path.join(DIR,'Data','df277.csv'),sep = ",").drop(columns="Unnamed: 0");
df278 = pd.read_csv(os.path.join(DIR,'Data','df278.csv'),sep = ",").drop(columns="Unnamed: 0");
df279 = pd.read_csv(os.path.join(DIR,'Data','df279.csv'),sep = ",").drop(columns="Unnamed: 0");

df280 = pd.read_csv(os.path.join(DIR,'Data','df280.csv'),sep = ",").drop(columns="Unnamed: 0");
df281 = pd.read_csv(os.path.join(DIR,'Data','df281.csv'),sep = ",").drop(columns="Unnamed: 0");
df282 = pd.read_csv(os.path.join(DIR,'Data','df282.csv'),sep = ",").drop(columns="Unnamed: 0");
df283 = pd.read_csv(os.path.join(DIR,'Data','df283.csv'),sep = ",").drop(columns="Unnamed: 0");
df284 = pd.read_csv(os.path.join(DIR,'Data','df284.csv'),sep = ",").drop(columns="Unnamed: 0");
df285 = pd.read_csv(os.path.join(DIR,'Data','df285.csv'),sep = ",").drop(columns="Unnamed: 0");
df286 = pd.read_csv(os.path.join(DIR,'Data','df286.csv'),sep = ",").drop(columns="Unnamed: 0");
df287 = pd.read_csv(os.path.join(DIR,'Data','df287.csv'),sep = ",").drop(columns="Unnamed: 0");
df288 = pd.read_csv(os.path.join(DIR,'Data','df288.csv'),sep = ",").drop(columns="Unnamed: 0");
df289 = pd.read_csv(os.path.join(DIR,'Data','df289.csv'),sep = ",").drop(columns="Unnamed: 0");

df290 = pd.read_csv(os.path.join(DIR,'Data','df290.csv'),sep = ",").drop(columns="Unnamed: 0");
df291 = pd.read_csv(os.path.join(DIR,'Data','df291.csv'),sep = ",").drop(columns="Unnamed: 0");
df292 = pd.read_csv(os.path.join(DIR,'Data','df292.csv'),sep = ",").drop(columns="Unnamed: 0");
df293 = pd.read_csv(os.path.join(DIR,'Data','df293.csv'),sep = ",").drop(columns="Unnamed: 0");
df294 = pd.read_csv(os.path.join(DIR,'Data','df294.csv'),sep = ",").drop(columns="Unnamed: 0");
df295 = pd.read_csv(os.path.join(DIR,'Data','df295.csv'),sep = ",").drop(columns="Unnamed: 0");
df296 = pd.read_csv(os.path.join(DIR,'Data','df296.csv'),sep = ",").drop(columns="Unnamed: 0");
df297 = pd.read_csv(os.path.join(DIR,'Data','df297.csv'),sep = ",").drop(columns="Unnamed: 0");
df298 = pd.read_csv(os.path.join(DIR,'Data','df298.csv'),sep = ",").drop(columns="Unnamed: 0");
df299 = pd.read_csv(os.path.join(DIR,'Data','df299.csv'),sep = ",").drop(columns="Unnamed: 0");

# %%
df300 = pd.read_csv(os.path.join(DIR,'Data','df300.csv'),sep = ",").drop(columns="Unnamed: 0");
df301 = pd.read_csv(os.path.join(DIR,'Data','df301.csv'),sep = ",").drop(columns="Unnamed: 0");
df302 = pd.read_csv(os.path.join(DIR,'Data','df302.csv'),sep = ",").drop(columns="Unnamed: 0");
df303 = pd.read_csv(os.path.join(DIR,'Data','df303.csv'),sep = ",").drop(columns="Unnamed: 0");
df304 = pd.read_csv(os.path.join(DIR,'Data','df304.csv'),sep = ",").drop(columns="Unnamed: 0");
df305 = pd.read_csv(os.path.join(DIR,'Data','df305.csv'),sep = ",").drop(columns="Unnamed: 0");
df306 = pd.read_csv(os.path.join(DIR,'Data','df306.csv'),sep = ",").drop(columns="Unnamed: 0");
df307 = pd.read_csv(os.path.join(DIR,'Data','df307.csv'),sep = ",").drop(columns="Unnamed: 0");
df308 = pd.read_csv(os.path.join(DIR,'Data','df308.csv'),sep = ",").drop(columns="Unnamed: 0");
df309 = pd.read_csv(os.path.join(DIR,'Data','df309.csv'),sep = ",").drop(columns="Unnamed: 0");

df310 = pd.read_csv(os.path.join(DIR,'Data','df310.csv'),sep = ",").drop(columns="Unnamed: 0");
df311 = pd.read_csv(os.path.join(DIR,'Data','df311.csv'),sep = ",").drop(columns="Unnamed: 0");
df312 = pd.read_csv(os.path.join(DIR,'Data','df312.csv'),sep = ",").drop(columns="Unnamed: 0");
df313 = pd.read_csv(os.path.join(DIR,'Data','df313.csv'),sep = ",").drop(columns="Unnamed: 0");
df314 = pd.read_csv(os.path.join(DIR,'Data','df314.csv'),sep = ",").drop(columns="Unnamed: 0");
df315 = pd.read_csv(os.path.join(DIR,'Data','df315.csv'),sep = ",").drop(columns="Unnamed: 0");
df316 = pd.read_csv(os.path.join(DIR,'Data','df316.csv'),sep = ",").drop(columns="Unnamed: 0");
df317 = pd.read_csv(os.path.join(DIR,'Data','df317.csv'),sep = ",").drop(columns="Unnamed: 0");
df318 = pd.read_csv(os.path.join(DIR,'Data','df318.csv'),sep = ",").drop(columns="Unnamed: 0");
df319 = pd.read_csv(os.path.join(DIR,'Data','df319.csv'),sep = ",").drop(columns="Unnamed: 0");

df320 = pd.read_csv(os.path.join(DIR,'Data','df320.csv'),sep = ",").drop(columns="Unnamed: 0");
df321 = pd.read_csv(os.path.join(DIR,'Data','df321.csv'),sep = ",").drop(columns="Unnamed: 0");
df322 = pd.read_csv(os.path.join(DIR,'Data','df322.csv'),sep = ",").drop(columns="Unnamed: 0");
df323 = pd.read_csv(os.path.join(DIR,'Data','df323.csv'),sep = ",").drop(columns="Unnamed: 0");
df324 = pd.read_csv(os.path.join(DIR,'Data','df324.csv'),sep = ",").drop(columns="Unnamed: 0");
df325 = pd.read_csv(os.path.join(DIR,'Data','df325.csv'),sep = ",").drop(columns="Unnamed: 0");
df326 = pd.read_csv(os.path.join(DIR,'Data','df326.csv'),sep = ",").drop(columns="Unnamed: 0");
df327 = pd.read_csv(os.path.join(DIR,'Data','df327.csv'),sep = ",").drop(columns="Unnamed: 0");
df328 = pd.read_csv(os.path.join(DIR,'Data','df328.csv'),sep = ",").drop(columns="Unnamed: 0");
df329 = pd.read_csv(os.path.join(DIR,'Data','df329.csv'),sep = ",").drop(columns="Unnamed: 0");

df330 = pd.read_csv(os.path.join(DIR,'Data','df330.csv'),sep = ",").drop(columns="Unnamed: 0");
df331 = pd.read_csv(os.path.join(DIR,'Data','df331.csv'),sep = ",").drop(columns="Unnamed: 0");
df332 = pd.read_csv(os.path.join(DIR,'Data','df332.csv'),sep = ",").drop(columns="Unnamed: 0");
df333 = pd.read_csv(os.path.join(DIR,'Data','df333.csv'),sep = ",").drop(columns="Unnamed: 0");
df334 = pd.read_csv(os.path.join(DIR,'Data','df334.csv'),sep = ",").drop(columns="Unnamed: 0");
df335 = pd.read_csv(os.path.join(DIR,'Data','df335.csv'),sep = ",").drop(columns="Unnamed: 0");
df336 = pd.read_csv(os.path.join(DIR,'Data','df336.csv'),sep = ",").drop(columns="Unnamed: 0");
df337 = pd.read_csv(os.path.join(DIR,'Data','df337.csv'),sep = ",").drop(columns="Unnamed: 0");
df338 = pd.read_csv(os.path.join(DIR,'Data','df338.csv'),sep = ",").drop(columns="Unnamed: 0");
df339 = pd.read_csv(os.path.join(DIR,'Data','df339.csv'),sep = ",").drop(columns="Unnamed: 0");

df340 = pd.read_csv(os.path.join(DIR,'Data','df340.csv'),sep = ",").drop(columns="Unnamed: 0");
df341 = pd.read_csv(os.path.join(DIR,'Data','df341.csv'),sep = ",").drop(columns="Unnamed: 0");
df342 = pd.read_csv(os.path.join(DIR,'Data','df342.csv'),sep = ",").drop(columns="Unnamed: 0");
df343 = pd.read_csv(os.path.join(DIR,'Data','df343.csv'),sep = ",").drop(columns="Unnamed: 0");
df344 = pd.read_csv(os.path.join(DIR,'Data','df344.csv'),sep = ",").drop(columns="Unnamed: 0");
df345 = pd.read_csv(os.path.join(DIR,'Data','df345.csv'),sep = ",").drop(columns="Unnamed: 0");
df346 = pd.read_csv(os.path.join(DIR,'Data','df346.csv'),sep = ",").drop(columns="Unnamed: 0");
df347 = pd.read_csv(os.path.join(DIR,'Data','df347.csv'),sep = ",").drop(columns="Unnamed: 0");
df348 = pd.read_csv(os.path.join(DIR,'Data','df348.csv'),sep = ",").drop(columns="Unnamed: 0");
df349 = pd.read_csv(os.path.join(DIR,'Data','df349.csv'),sep = ",").drop(columns="Unnamed: 0");

df350 = pd.read_csv(os.path.join(DIR,'Data','df350.csv'),sep = ",").drop(columns="Unnamed: 0");
df351 = pd.read_csv(os.path.join(DIR,'Data','df351.csv'),sep = ",").drop(columns="Unnamed: 0");
df352 = pd.read_csv(os.path.join(DIR,'Data','df352.csv'),sep = ",").drop(columns="Unnamed: 0");
df353 = pd.read_csv(os.path.join(DIR,'Data','df353.csv'),sep = ",").drop(columns="Unnamed: 0");
df354 = pd.read_csv(os.path.join(DIR,'Data','df354.csv'),sep = ",").drop(columns="Unnamed: 0");
df355 = pd.read_csv(os.path.join(DIR,'Data','df355.csv'),sep = ",").drop(columns="Unnamed: 0");
df356 = pd.read_csv(os.path.join(DIR,'Data','df356.csv'),sep = ",").drop(columns="Unnamed: 0");
df357 = pd.read_csv(os.path.join(DIR,'Data','df357.csv'),sep = ",").drop(columns="Unnamed: 0");
df358 = pd.read_csv(os.path.join(DIR,'Data','df358.csv'),sep = ",").drop(columns="Unnamed: 0");
df359 = pd.read_csv(os.path.join(DIR,'Data','df359.csv'),sep = ",").drop(columns="Unnamed: 0");

df360 = pd.read_csv(os.path.join(DIR,'Data','df360.csv'),sep = ",").drop(columns="Unnamed: 0");
df361 = pd.read_csv(os.path.join(DIR,'Data','df361.csv'),sep = ",").drop(columns="Unnamed: 0");
df362 = pd.read_csv(os.path.join(DIR,'Data','df362.csv'),sep = ",").drop(columns="Unnamed: 0");
df363 = pd.read_csv(os.path.join(DIR,'Data','df363.csv'),sep = ",").drop(columns="Unnamed: 0");
df364 = pd.read_csv(os.path.join(DIR,'Data','df364.csv'),sep = ",").drop(columns="Unnamed: 0");
df365 = pd.read_csv(os.path.join(DIR,'Data','df365.csv'),sep = ",").drop(columns="Unnamed: 0");
df366 = pd.read_csv(os.path.join(DIR,'Data','df366.csv'),sep = ",").drop(columns="Unnamed: 0");
df367 = pd.read_csv(os.path.join(DIR,'Data','df367.csv'),sep = ",").drop(columns="Unnamed: 0");
df368 = pd.read_csv(os.path.join(DIR,'Data','df368.csv'),sep = ",").drop(columns="Unnamed: 0");
df369 = pd.read_csv(os.path.join(DIR,'Data','df369.csv'),sep = ",").drop(columns="Unnamed: 0");

df370 = pd.read_csv(os.path.join(DIR,'Data','df370.csv'),sep = ",").drop(columns="Unnamed: 0");
df371 = pd.read_csv(os.path.join(DIR,'Data','df371.csv'),sep = ",").drop(columns="Unnamed: 0");
df372 = pd.read_csv(os.path.join(DIR,'Data','df372.csv'),sep = ",").drop(columns="Unnamed: 0");
df373 = pd.read_csv(os.path.join(DIR,'Data','df373.csv'),sep = ",").drop(columns="Unnamed: 0");
df374 = pd.read_csv(os.path.join(DIR,'Data','df374.csv'),sep = ",").drop(columns="Unnamed: 0");
df375 = pd.read_csv(os.path.join(DIR,'Data','df375.csv'),sep = ",").drop(columns="Unnamed: 0");
df376 = pd.read_csv(os.path.join(DIR,'Data','df376.csv'),sep = ",").drop(columns="Unnamed: 0");
df377 = pd.read_csv(os.path.join(DIR,'Data','df377.csv'),sep = ",").drop(columns="Unnamed: 0");
df378 = pd.read_csv(os.path.join(DIR,'Data','df378.csv'),sep = ",").drop(columns="Unnamed: 0");

# %%
dfs = [df1, \
       df2, \
       df3, \
       df4, \
       df5, \
       df6, \
       df7, \
       df8, \
       df9, \
       df10,\
       df11,\
       df12,\
       df13,\
       df14,\
       df15,\
       df16,\
       df17,\
       df18,\
       df19,\
       df20,\
       df21,\
       df22,\
       df23,\
       df24,\
       df25,\
       df26,\
       df27,\
       df28,\
       df29,\
       df30,\
       df31,\
       df32,\
       df33,\
       df34,\
       df35,\
       df36,\
       df37,\
       df38,\
       df39,\
       df40,\
       df41,\
       df42,\
       df43,\
       df44,\
       df45,\
       df46,\
       df47,\
       df48,\
       df49,\
       df50,\
       df51,\
       df52,\
       df53,\
       df54,\
       df55,\
       df56,\
       df57,\
       df58,\
       df59,\
       df60,\
       df61,\
       df62,\
       df63,\
       df64,\
       df65,\
       df66,\
       df67,\
       df68,\
       df69,\
       df70,\
       df71,\
       df72,\
       df73,\
       df74,\
       df75,\
       df76,\
       df77,\
       df78,\
       df79,\
       df80,\
       df81,\
       df82,\
       df83,\
       df84,\
       df85,\
       df86,\
       df87,\
       df88,\
       df89,\
       df90,\
       df91,\
       df92,\
       df93,\
       df94,\
       df95,\
       df96,\
       df97,\
       df98,\
       df99,\
       df100,\
       df101,\
       df102,\
       df103,\
       df104,\
       df105,\
       df106,\
       df107,\
       df108,\
       df109,\
       df110,\
       df111,\
       df112,\
       df113,\
       df114,\
       df115,\
       df116,\
       df117,\
       df118,\
       df119,\
       df120,\
       df121,\
       df122,\
       df123,\
       df124,\
       df125,\
       df126,\
       df127,\
       df128,\
       df129,\
       df130,\
       df131,\
       df132,\
       df133,\
       df134,\
       df135,\
       df136,\
       df137,\
       df138,\
       df139,\
       df140,\
       df141,\
       df142,\
       df143,\
       df144,\
       df145,\
       df146,\
       df147,\
       df148,\
       df149,\
       df150,\
       df151,\
       df152,\
       df153,\
       df154,\
       df155,\
       df156,\
       df157,\
       df158,\
       df159,\
       df160,\
       df161,\
       df162,\
       df163,\
       df164,\
       df165,\
       df166,\
       df167,\
       df168,\
       df169,\
       df170,\
       df171,\
       df172,\
       df173,\
       df174,\
       df175,\
       df176,\
       df177,\
       df178,\
       df179,\
       df180,\
       df181,\
       df182,\
       df183,\
       df184,\
       df185,\
       df186,\
       df187,\
       df188,\
       df189,\
       df190,\
       df191,\
       df192,\
       df193,\
       df194,\
       df195,\
       df196,\
       df197,\
       df198,\
       df199,\
       df200,\
       df201,\
       df202,\
       df203,\
       df204,\
       df205,\
       df206,\
       df207,\
       df208,\
       df209,\
       df210,\
       df211,\
       df212,\
       df213,\
       df214,\
       df215,\
       df216,\
       df217,\
       df218,\
       df219,\
       df220,\
       df221,\
       df222,\
       df223,\
       df224,\
       df225,\
       df226,\
       df227,\
       df228,\
       df229,\
       df230,\
       df231,\
       df232,\
       df233,\
       df234,\
       df235,\
       df236,\
       df237,\
       df238,\
       df239,\
       df240,\
       df241,\
       df242,\
       df243,\
       df244,\
       df245,\
       df246,\
       df247,\
       df248,\
       df249,\
       df250,\
       df251,\
       df252,\
       df253,\
       df254,\
       df255,\
       df256,\
       df257,\
       df258,\
       df259,\
       df260,\
       df261,\
       df262,\
       df263,\
       df264,\
       df265,\
       df266,\
       df267,\
       df268,\
       df269,\
       df270,\
       df271,\
       df272,\
       df273,\
       df274,\
       df275,\
       df276,\
       df277,\
       df278,\
       df279,\
       df280,\
       df281,\
       df282,\
       df283,\
       df284,\
       df285,\
       df286,\
       df287,\
       df288,\
       df289,\
       df290,\
       df291,\
       df292,\
       df293,\
       df294,\
       df295,\
       df296,\
       df297,\
       df298,\
       df299,\
       df300,\
       df301,\
       df302,\
       df303,\
       df304,\
       df305,\
       df306,\
       df307,\
       df308,\
       df309,\
       df310,\
       df311,\
       df312,\
       df313,\
       df314,\
       df315,\
       df316,\
       df317,\
       df318,\
       df319,\
       df320,\
       df321,\
       df322,\
       df323,\
       df324,\
       df325,\
       df326,\
       df327,\
       df328,\
       df329,\
       df330,\
       df331,\
       df332,\
       df333,\
       df334,\
       df335,\
       df336,\
       df337,\
       df338,\
       df339,\
       df340,\
       df341,\
       df342,\
       df343,\
       df344,\
       df345,\
       df346,\
       df347,\
       df348,\
       df349,\
       df350,\
       df351,\
       df352,\
       df353,\
       df354,\
       df355,\
       df356,\
       df357,\
       df358,\
       df359,\
       df360,\
       df361,\
       df362,\
       df363,\
       df364,\
       df365,\
       df366,\
       df367,\
       df368,\
       df369,\
       df370,\
       df371,\
       df372,\
       df373,\
       df374,\
       df375,\
       df376,\
       df377,\
       df378]

# %% [raw]
# dfs      = []
# csv      = 26
#
# for df in range(1,csv+1):
#     csv_name = "df"+str(csv)+".csv"
#     temp     = pd.read_csv(os.path.join(DIR,'Data',csv_name),sep = ",").drop(columns="Unnamed: 0");
#     dfs.append(temp)

# %%
dataset = pd.concat(dfs).drop_duplicates().reset_index(drop=True)

dataset['data'] = pd.to_datetime(dataset['data'])
dataset = dataset.sort_values(by=['data'])
dataset.reset_index(drop=True, inplace=True)

# %%
dataset.head()
# Out:
#                  data  velocità vento [km/h] cardinalità vento  \
# 0 2021-12-20 16:49:00                    4.3                 N
# 1 2021-12-20 16:54:00                    6.4                 W
# 2 2021-12-20 16:59:00                    7.6                NW
# 3 2021-12-20 17:04:00                    6.4               WNW
# 4 2021-12-20 17:09:00                    7.6               WNW
#
#    direzione vento [°]  pioggia cumulata [mm]  pioggia istantanea [mm]  \
# 0                352.0                    0.0                      0.0
# 1                279.0                    0.0                      0.0
# 2                326.0                    0.0                      0.0
# 3                298.0                    0.0                      0.0
# 4                283.0                    0.0                      0.0
#
#    pressione [hPa]  temperatura di rugiada [°C]  umidità relativa [%]  \
# 0           1017.7                          7.3                    66
# ...

# %%
dataset.tail()
# Out:
#                      data  velocità vento [km/h] cardinalità vento  \
# 61530 2022-07-31 06:14:00                    7.2                NW
# 61531 2022-07-31 06:19:00                   10.8                 W
# 61532 2022-07-31 06:24:00                   17.2               WNW
# 61533 2022-07-31 06:29:00                    8.7               NNW
# 61534 2022-07-31 06:34:00                    6.9                NW
#
#        direzione vento [°]  pioggia cumulata [mm]  pioggia istantanea [mm]  \
# 61530                309.0                    0.0                      0.0
# 61531                269.0                    0.0                      0.0
# 61532                294.0                    0.0                      0.0
# 61533                333.0                    0.0                      0.0
# 61534                307.0                    0.0                      0.0
#
#        pressione [hPa]  temperatura di rugiada [°C]  umidità relativa [%]  \
# ...

# %%
temp_dataset = dataset
mantissa     = 2

for row in range (0,len(dataset)):
    if(row>0):
        data_a  = pd.to_datetime(dataset.loc[row-1,"data"])
        data_b  = pd.to_datetime(dataset.loc[row,"data"])
        dt_pace = pd.Timedelta("0 days 00:05:00")
        gap     = int((data_b-data_a)/("0 days 00:05:00"))
        
        vv_a    = dataset.loc[row-1,"velocità vento [km/h]"]
        vv_b    = dataset.loc[row  ,"velocità vento [km/h]"]
        vv_pace = abs((vv_b-vv_a))/(gap+0.000000000001)
        
        dv_a    = dataset.loc[row-1,"direzione vento [°]"]
        dv_b    = dataset.loc[row  ,"direzione vento [°]"]
        dv_pace = abs((dv_b-dv_a))/(gap+0.000000000001)
        
        pc_a    = dataset.loc[row-1,"pioggia cumulata [mm]"]
        pc_b    = dataset.loc[row  ,"pioggia cumulata [mm]"]
        pc_pace = abs((pc_b-pc_a))/(gap+0.000000000001)
                
        pi_a    = dataset.loc[row-1,"pioggia istantanea [mm]"]
        pi_b    = dataset.loc[row  ,"pioggia istantanea [mm]"]
        pi_pace = abs((pi_b-pi_a))/(gap+0.000000000001)
                
        p_a     = dataset.loc[row-1,"pressione [hPa]"]
        p_b     = dataset.loc[row  ,"pressione [hPa]"]
        p_pace  = abs((p_b-p_a))/(gap+0.000000000001)  
        
        tr_a    = dataset.loc[row-1,"temperatura di rugiada [°C]"]
        tr_b    = dataset.loc[row  ,"temperatura di rugiada [°C]"]
        tr_pace = abs((tr_b-tr_a))/(gap+0.000000000001) 
        
        ur_a    = dataset.loc[row-1,"umidità relativa [%]"]
        ur_b    = dataset.loc[row  ,"umidità relativa [%]"]
        ur_pace = abs((ur_b-ur_a))/(gap+0.000000000001)
        
        t_a     = dataset.loc[row-1,"temperatura [°C]"]
        t_b     = dataset.loc[row  ,"temperatura [°C]"]
        t_pace  = abs((t_b-t_a))/(gap+0.000000000001)
        
    
        if(gap>1):
            print("GAP FOUND ***********************************************************************************************")
            print("Data A:          "+str(data_a))
            print("Data B:          "+str(data_b))
            print("Missing Records: "+str(gap-1))
            
            for i in range (1,gap): 
                data_c = data_a       + i*dt_pace
                
                vv_c = 0
                dv_c = 0
                pc_c = 0
                pi_c = 0
                p_c  = 0
                tr_c = 0
                ur_c = 0
                t_c  = 0
                
                if(vv_a<=vv_b): vv_c = round(vv_a + i*vv_pace,mantissa)
                if(vv_a> vv_b): vv_c = round(vv_a - i*vv_pace,mantissa)
            
                if(dv_a<=dv_b): dv_c = round(dv_a + i*dv_pace,mantissa)
                if(dv_a> dv_b): dv_c = round(dv_a - i*dv_pace,mantissa)
                
                if(pc_a<=pc_b): pc_c = round(pc_a + i*pc_pace,mantissa)
                if(pc_a> pc_b): pc_c = round(pc_a - i*pc_pace,mantissa)
                    
                if(pi_a<=pi_b): pi_c = round(pi_a + i*pi_pace,mantissa)
                if(pi_a> pi_b): pi_c = round(pi_a - i*pi_pace,mantissa)
                    
                if(p_a<=p_b):   p_c  = round(p_a  + i*p_pace ,mantissa)
                if(p_a> p_b):   p_c  = round(p_a  - i*p_pace ,mantissa)       
                    
                if(tr_a<=tr_b): tr_c = round(tr_a + i*tr_pace,mantissa)
                if(tr_a> tr_b): tr_c = round(tr_a - i*tr_pace,mantissa)                     
                
                if(ur_a<=ur_b): ur_c = round(ur_a + i*ur_pace,mantissa)
                if(ur_a> ur_b): ur_c = round(ur_a - i*ur_pace,mantissa) 
                
                if(t_a<=t_b):   t_c  = round(t_a  + i*t_pace ,mantissa)
                if(t_a> t_b):   t_c  = round(t_a  - i*t_pace ,mantissa)
                
                vdc = "none"
                
                if (dv_c <= 11.25):                    vdc = 'N'       
                if (dv_c >= 348.75):                   vdc = 'N'       
                if (dv_c > 11.25  and dv_c <= 33.75):  vdc = 'NNE'
                if (dv_c > 33.75  and dv_c <= 56.25):  vdc = 'NE'
                if (dv_c > 56.25  and dv_c <= 78.75):  vdc = 'ENE'
                if (dv_c > 78.75  and dv_c <= 101.25): vdc = 'E'
                if (dv_c > 101.25 and dv_c <= 123.75): vdc = 'ESE'
                if (dv_c > 123.75 and dv_c <= 146.25): vdc = 'SE'
                if (dv_c > 146.25 and dv_c <= 168.75): vdc = 'SSE'
                if (dv_c > 168.75 and dv_c <= 191.25): vdc = 'S'
                if (dv_c > 191.25 and dv_c <= 213.75): vdc = 'SSW'
                if (dv_c > 213.75 and dv_c <= 236.25): vdc = 'SW'
                if (dv_c > 236.25 and dv_c <= 258.75): vdc = 'WSW'
                if (dv_c > 258.75 and dv_c <= 281.25): vdc = 'W'
                if (dv_c > 281.25 and dv_c <= 303.75): vdc = 'WNW'
                if (dv_c > 303.75 and dv_c <= 326.25): vdc = 'NW'
                if (dv_c > 326.75 and dv_c <= 348.75): vdc = 'NNW'
                if (dv_c == 0     ): vdc = 'N'
                if (dv_c == 22.5  ): vdc = 'NNE'
                if (dv_c == 45    ): vdc = 'NE'
                if (dv_c == 67.5  ): vdc = 'ENE'
                if (dv_c == 90    ): vdc = 'E'
                if (dv_c == 112.5 ): vdc = 'ESE'
                if (dv_c == 135   ): vdc = 'SE'
                if (dv_c == 157.5 ): vdc = 'SSE'
                if (dv_c == 180   ): vdc = 'S'
                if (dv_c == 202.5 ): vdc = 'SSW'
                if (dv_c == 225   ): vdc = 'SW'
                if (dv_c == 247.5 ): vdc = 'WSW'
                if (dv_c == 270   ): vdc = 'W'
                if (dv_c == 292.5 ): vdc = 'WNW'
                if (dv_c == 315   ): vdc = 'NW'
                if (dv_c == 337.5 ): vdc = 'NNW'
                if (dv_c == 360   ): vdc = 'N'
                                        
                string = str(data_c)+" "\
                        +str(vv_c)+" "\
                        +str(dv_c)+" "\
                        +str(pc_c)+" "\
                        +str(pi_c)+" "\
                        +str(p_c) +" "\
                        +str(tr_c)+" "\
                        +str(ur_c)+" "\
                        +str(t_c) +" "\
                        +vdc
                
                dataset.loc[len(dataset)+1,"data"]                        = data_c
                dataset.loc[len(dataset)  ,"velocità vento [km/h]"]       = vv_c
                dataset.loc[len(dataset)  ,"cardinalità vento"]           = vdc
                dataset.loc[len(dataset)  ,"direzione vento [°]"]         = dv_c
                dataset.loc[len(dataset)  ,"pioggia cumulata [mm]"]       = pc_c
                dataset.loc[len(dataset)  ,"pioggia istantanea [mm]"]     = pi_c
                dataset.loc[len(dataset)  ,"pressione [hPa]"]             = p_c
                dataset.loc[len(dataset)  ,"temperatura di rugiada [°C]"] = tr_c
                dataset.loc[len(dataset)  ,"umidità relativa [%]"]        = ur_c
                dataset.loc[len(dataset)  ,"temperatura [°C]"]            = t_c

                print(string)
                
# note: forse c'è un bug con i missing records
# Out:
# GAP FOUND ***********************************************************************************************
# Data A:          2021-12-21 14:59:00
# Data B:          2021-12-21 15:09:00
# Missing Records: 1
# 2021-12-21 15:04:00 0.9 356.0 3.95 0.15 1024.15 7.5 87.5 9.5 N
# GAP FOUND ***********************************************************************************************
# Data A:          2021-12-21 23:04:00
# Data B:          2021-12-21 23:19:00
# Missing Records: 2
# 2021-12-21 23:09:00 2.63 303.0 0.07 0.07 1024.87 7.07 92.0 8.27 WNW
# 2021-12-21 23:14:00 3.47 302.0 0.13 0.13 1024.83 7.03 92.0 8.23 WNW
# GAP FOUND ***********************************************************************************************
# Data A:          2021-12-21 23:34:00
# Data B:          2021-12-22 02:09:00
# Missing Records: 30
# 2021-12-21 23:39:00 2.33 286.65 0.21 0.02 1024.59 7.09 91.97 8.3 WNW
# 2021-12-21 23:44:00 2.56 285.29 0.22 0.03 1024.57 7.09 91.94 8.29 WNW
# ...

# %%
dataset['data'] = pd.to_datetime(dataset['data'])
dataset = dataset.sort_values(by=['data'])
dataset.reset_index(drop=True, inplace=True)

# %% [raw]
# df = dataset
#
# hours_earlier   = 3
# time_window_h   = 3
# init_steps_back = int((hours_earlier)*60/5 - 1)
# steps_back      = int((hours_earlier+time_window_h)*60/5)
#
# #hours_earlier   = 0
# #time_window_h   = 2
# #init_steps_back = 0
# #steps_back      = int((hours_earlier+time_window_h)*60/5)
#
# for i in range(init_steps_back,steps_back):
#
#     print ("Creating (n-"+str(i+1)+") features...")
#
#     vv_sb  =  "velocità vento [km/h] (n-"       +str(i+1)+")"
#     cv_sb  =  "cardinalità vento (n-"           +str(i+1)+")"
#     dv_sb  =  "direzione vento [°] (n-"         +str(i+1)+")"
#     pc_sb  =  "pioggia cumulata [mm] (n-"       +str(i+1)+")"
#     pi_sb  =  "pioggia istantanea [mm] (n-"     +str(i+1)+")"
#     p_sb   =  "pressione [hPa] (n-"             +str(i+1)+")"
#     tr_sb  =  "temperatura di rugiada [°C] (n-" +str(i+1)+")"
#     ur_sb  =  "umidità relativa [%] (n-"        +str(i+1)+")"
#     t_sb   =  "temperatura [°C] (n-"            +str(i+1)+")"
#
#     df[vv_sb] = 0
#     df[cv_sb] = 0
#     df[dv_sb] = 0
#     df[pc_sb] = 0
#     df[pi_sb] = 0
#     df[p_sb]  = 0
#     df[tr_sb] = 0
#     df[ur_sb] = 0
#     df[t_sb]  = 0
#
#
#     for row in range(0, len(df)):
#         if(row>i):
#
#             df.loc[row,vv_sb]  =  df.loc[row-(i+1),"velocità vento [km/h]"]
#             df.loc[row,cv_sb]  =  df.loc[row-(i+1),"cardinalità vento"]
#             df.loc[row,dv_sb]  =  df.loc[row-(i+1),"direzione vento [°]"]
#             df.loc[row,pc_sb]  =  df.loc[row-(i+1),"pioggia cumulata [mm]"]
#             df.loc[row,pi_sb]  =  df.loc[row-(i+1),"pioggia istantanea [mm]"]
#             df.loc[row, p_sb]  =  df.loc[row-(i+1),"pressione [hPa]"]
#             df.loc[row,tr_sb]  =  df.loc[row-(i+1),"temperatura di rugiada [°C]"]
#             df.loc[row,ur_sb]  =  df.loc[row-(i+1),"umidità relativa [%]"]
#             df.loc[row, t_sb]  =  df.loc[row-(i+1),"temperatura [°C]"]
#
#
# df.tail()

# %% [raw]
# temp_dataframe  = df;
# indexesTD = []
# for row in range(0,steps_back):
#     indexesTD.append(row)
# temp_dataframe = temp_dataframe.drop(indexesTD)
# temp_dataframe.reset_index(drop=True, inplace=True)
# print(str(len(indexesTD))+" records deleted, "+str(len(temp_dataframe))+" left")
# df = temp_dataframe;
#
# df.head()
#
# dataset = df

# %%
#TA = Ta + 0.33*e -0.7*V -4
#Ta : temperatura (°C)
#e  : pressione di vapore
#e  = rh/100 * 6.105 * nepero^((17.27*Ta)/(237.7+Ta))
#V  : velocità vento (m/s)
#rh : umidità relativa (%)

nepero = 2.718
dataset['temperatura percepita [°C]']=0

for row in range(0,len(dataset)):
    V    = float(dataset.loc[row,'velocità vento [km/h]'])
    Ta   = float(dataset.loc[row,'temperatura [°C]'])
    rh   = float(dataset.loc[row,'umidità relativa [%]'])
    
    Vms  = V*(10/36)
    e    = rh/100 * 6.105 * nepero**((17.27*Ta)/(237.7+Ta))
    TA   = round(Ta + 0.33*e -0.7*Vms -4,2)
    
    dataset.loc[row,'temperatura percepita [°C]'] = TA

# %%
import datetime 

dataset['ora']  = 0
dataset['mese'] = 0

for row in range(0,len(dataset)):
    temp = int(dataset.loc[row,'data'].hour)*60 + int(dataset.loc[row,'data'].minute)
    dataset.loc[row,'ora'] = datetime.timedelta(minutes=temp)
    
for row in range(0,len(dataset)):
    temp = int(dataset.loc[row,'data'].month)
    dataset.loc[row,'mese'] = temp
    
dataset.head()
# Out:
#                  data  velocità vento [km/h] cardinalità vento  \
# 0 2021-12-20 16:49:00                    4.3                 N
# 1 2021-12-20 16:54:00                    6.4                 W
# 2 2021-12-20 16:59:00                    7.6                NW
# 3 2021-12-20 17:04:00                    6.4               WNW
# 4 2021-12-20 17:09:00                    7.6               WNW
#
#    direzione vento [°]  pioggia cumulata [mm]  pioggia istantanea [mm]  \
# 0                352.0                    0.0                      0.0
# 1                279.0                    0.0                      0.0
# 2                326.0                    0.0                      0.0
# 3                298.0                    0.0                      0.0
# 4                283.0                    0.0                      0.0
#
#    pressione [hPa]  temperatura di rugiada [°C]  umidità relativa [%]  \
# 0           1017.7                          7.3                  66.0
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

data = dataset.loc[len(dataset)-1,"data"]

inf_lim = 0

WD = dataset.loc[inf_lim:len(dataset)-1,'direzione vento [°]']
WV = dataset.loc[inf_lim:len(dataset)-1,'velocità vento [km/h]']
WD_R = ((2*3.14159265)/360)*WD

r     = WV
theta = WD_R

hue = np.arange(len(WD_R))

fig = plt.figure(figsize=(5,5),dpi=150)

ax = fig.add_subplot(projection='polar')
ax.set_theta_zero_location("N")
ax.set_theta_direction(-1)

angles= [0,22.5,45,67.5,90,112.5,135,157.5,180,202.5,225,247.5,270,292.5,315,337.5]
ax.set_thetagrids(angles)
ax.set_xticklabels(['N','NNE','NE','ENE','E','ESE','SE','SSE','S','SSW','SW','WSW','W','WNW','NW','NNW'])
ax.grid(color='lightgray', linestyle='-', linewidth=0.3)

ax.set_title("Velocità vento [Km/h], aggiornato al "+str(data), va='bottom', fontsize=8)

c = ax.scatter(theta, r, s=8, alpha=1,c=hue,cmap='plasma')

# %%
dataset.to_csv(r'full_dataset.csv')

# %%
wind = dataset.loc[:,['direzione vento [°]', 'velocità vento [km/h]']]
wind.head()
wind.to_csv(r'wind.csv')
